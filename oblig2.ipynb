# %% [markdown]
# Assignment 2
#
# Task 1. Using selection sort
# with the following list to sort:
# [ 1502, 1560, 1600, 1540, 100, 1660, 1700, 2024 ]
# The partially sorted list after 3 passes of selection sort is:
# [100, 1502, 1540, 1600, 1560, 1660, 1700, 2024]
#
# Explain how it works:

# %% [markdown]
# Task 2 Using Bubble sort
# Suppose you have the following list of numbers to sort:
# [ 400, 10, 210, 160, 70, 220, 280, 380, 180, 260, 540 ]
#  What will be the partially sorted list after 3 passes of Bubble Sort?
# 1 pass[10, 400, 210, 160, 70, 220, 280, 380, 180, 260, 540]
# 2 pass[10, 210, 400, 160, 70, 220, 280, 380, 180, 260, 540]
# 3 pass[10, 210, 160, 400, 70, 220, 280, 380, 180, 260, 540]
